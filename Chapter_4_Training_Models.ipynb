# %% [markdown]
# <a href="https://colab.research.google.com/github/Rehanabbaxi/Machine_Learning_Practice/blob/main/Chapter_4_Training_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(42)
m =  100

X = 2 + np.random.rand(m  , 1)
y = 4 +3 * X + np.random.randn(m , 1 )
